# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('watertrain.csv')
train.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... payment_type  \
# 0  34.938093  -9.856322                  none            0  ...     annually
# 1  34.698766  -2.147466              Zahanati            0  ...    never pay
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...   per bucket
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...    never pay
# 4  31.130847  -1.825359               Shuleni            0  ...    never pay
#
#   water_quality quality_group      quantity  quantity_group  \
# 0          soft          good        enough          enough
# 1          soft          good  insufficient    insufficient
# 2          soft          good        enough          enough
# 3          soft          good           dry             dry
# 4          soft          good      seasonal        seasonal
#
#                  source           source_type  source_class  \
# 0                spring                spring   groundwater
# 1  rainwater harvesting  rainwater harvesting       surface
# 2                   dam                   dam       surface
# 3           machine dbh              borehole   groundwater
# 4  rainwater harvesting  rainwater harvesting       surface
#
#                waterpoint_type waterpoint_type_group
# 0           communal standpipe    communal standpipe
# 1           communal standpipe    communal standpipe
# 2  communal standpipe multiple    communal standpipe
# 3  communal standpipe multiple    communal standpipe
# 4           communal standpipe    communal standpipe
#
# [5 rows x 40 columns]

# %%
print(train.shape)
# Out:
# (59400, 40)

# %%
target = pd.read_csv('watertarget.csv')
target.head()
# Out:
#       id    status_group
# 0  69572      functional
# 1   8776      functional
# 2  34310      functional
# 3  67743  non functional
# 4  19728      functional

# %%
print(target.shape)
# Out:
# (59400, 2)

# %%
df = pd.merge(train, target)
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  ... water_quality  \
# 0  34.938093  -9.856322                  none            0  ...          soft
# 1  34.698766  -2.147466              Zahanati            0  ...          soft
# 2  37.460664  -3.821329           Kwa Mahundi            0  ...          soft
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0  ...          soft
# 4  31.130847  -1.825359               Shuleni            0  ...          soft
#
#   quality_group      quantity  quantity_group                source  \
# 0          good        enough          enough                spring
# 1          good  insufficient    insufficient  rainwater harvesting
# 2          good        enough          enough                   dam
# 3          good           dry             dry           machine dbh
# 4          good      seasonal        seasonal  rainwater harvesting
#
#             source_type source_class              waterpoint_type  \
# 0                spring  groundwater           communal standpipe
# 1  rainwater harvesting      surface           communal standpipe
# 2                   dam      surface  communal standpipe multiple
# 3              borehole  groundwater  communal standpipe multiple
# 4  rainwater harvesting      surface           communal standpipe
#
#   waterpoint_type_group    status_group
# 0    communal standpipe      functional
# 1    communal standpipe      functional
# 2    communal standpipe      functional
# 3    communal standpipe  non functional
# 4    communal standpipe      functional
#
# [5 rows x 41 columns]

# %%
df['region_code'].value_counts()
# Out:
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64

# %%
df['district_code'].value_counts()
# Out:
# 1     12203
# 2     11173
# 3      9998
# 4      8999
# 5      4356
# 6      4074
# 7      3343
# 8      1043
# 30      995
# 33      874
# 53      745
# 43      505
# 13      391
# 23      293
# 63      195
# 62      109
# 60       63
# 0        23
# 80       12
# 67        6
# Name: district_code, dtype: int64

# %%
df['lga'].value_counts()
# Out:
# Njombe          2503
# Arusha Rural    1252
# Moshi Rural     1251
# Bariadi         1177
# Rungwe          1106
#                 ...
# Moshi Urban       79
# Kigoma Urban      71
# Arusha Urban      63
# Lindi Urban       21
# Nyamagana          1
# Name: lga, Length: 125, dtype: int64

# %%
df['ward'].value_counts()
# Out:
# Igosi        307
# Imalinyi     252
# Siha Kati    232
# Mdandu       231
# Nduruma      217
#             ...
# Ukata          1
# Nyamtinga      1
# Burungura      1
# Kinungu        1
# Ikweha         1
# Name: ward, Length: 2092, dtype: int64

# %% [markdown]
# # Unnessary Columns for preditive model

# %%
pred_uncol = ['date_recorded','funder','installer','longitude','latitude','wpt_name','num_private','subvillage',
             'public_meeting','recorded_by','scheme_name',
             'extraction_type','management','payment','water_quality','source_type',
             'waterpoint_type_group','permit']

# %%
pred_df = df.drop(pred_uncol,axis=1)
pred_df.head()
# Out:
#       id  amount_tsh  gps_height                    basin   region  \
# 0  69572      6000.0        1390               Lake Nyasa   Iringa
# 1   8776         0.0        1399            Lake Victoria     Mara
# 2  34310        25.0         686                  Pangani  Manyara
# 3  67743         0.0         263  Ruvuma / Southern Coast   Mtwara
# 4  19728         0.0           0            Lake Victoria   Kagera
#
#    region_code  district_code        lga        ward  population  ...  \
# 0           11              5     Ludewa    Mundindi         109  ...
# 1           20              2  Serengeti       Natta         280  ...
# 2           21              4  Simanjiro     Ngorika         250  ...
# 3           90             63   Nanyumbu    Nanyumbu          58  ...
# 4           18              1    Karagwe  Nyakasimbi           0  ...
#
#   extraction_type_class  management_group payment_type quality_group  \
# 0               gravity        user-group     annually          good
# 1               gravity        user-group    never pay          good
# 2               gravity        user-group   per bucket          good
# 3           submersible        user-group    never pay          good
# 4               gravity             other    never pay          good
#
#        quantity quantity_group                source source_class  \
# 0        enough         enough                spring  groundwater
# 1  insufficient   insufficient  rainwater harvesting      surface
# 2        enough         enough                   dam      surface
# 3           dry            dry           machine dbh  groundwater
# 4      seasonal       seasonal  rainwater harvesting      surface
#
#                waterpoint_type    status_group
# 0           communal standpipe      functional
# 1           communal standpipe      functional
# 2  communal standpipe multiple      functional
# 3  communal standpipe multiple  non functional
# 4           communal standpipe      functional
#
# [5 rows x 23 columns]

# %%
pred_df.isna().sum()
# Out:
# id                          0
# amount_tsh                  0
# gps_height                  0
# basin                       0
# region                      0
# region_code                 0
# district_code               0
# lga                         0
# ward                        0
# population                  0
# scheme_management        3877
# construction_year           0
# extraction_type_group       0
# extraction_type_class       0
# management_group            0
# payment_type                0
# quality_group               0
# quantity                    0
# quantity_group              0
# source                      0
# source_class                0
# waterpoint_type             0
# status_group                0
# dtype: int64

# %%
pred_df[pred_df.isna().any(axis=1)]
# Out:
#           id  amount_tsh  gps_height                    basin     region  \
# 4      19728         0.0           0            Lake Victoria     Kagera
# 7      54551         0.0           0          Lake Tanganyika  Shinyanga
# 9      46144         0.0           0            Lake Victoria     Kagera
# 18     34169         0.0        1162            Lake Victoria     Mwanza
# 27     20145         0.0           0            Lake Victoria     Kagera
# ...      ...         ...         ...                      ...        ...
# 59329  27957         0.0           0            Lake Victoria  Shinyanga
# 59344   6450         0.0        1303                 Internal     Arusha
# 59362  18917         0.0        2190               Lake Nyasa     Iringa
# 59370  14796       200.0        1154          Lake Tanganyika     Kigoma
# 59383  44616         0.0          11  Ruvuma / Southern Coast      Lindi
#
#        region_code  district_code          lga          ward  population  ...  \
# 4               18              1      Karagwe    Nyakasimbi           0  ...
# 7               17              3       Kahama        Chambo           0  ...
# 9               18              1      Karagwe        Kaisho           0  ...
# 18              19              1      Ukerewe      Ilangala        1000  ...
# 27              18              1      Karagwe     Nyaishozi           0  ...
# ...            ...            ...          ...           ...         ...  ...
# 59329           17              3       Kahama       Malunga           0  ...
# 59344            2              7         Meru  Ngarenanyuki         230  ...
# 59362           11              4       Njombe       Luponde          60  ...
# 59370           16              2       Kasulu        Rusesa           1  ...
# 59383           80             62  Lindi Urban       Jamhuri         800  ...
#
#       extraction_type_class  management_group payment_type quality_group  \
# 4                   gravity             other    never pay          good
# 7                  handpump        user-group      unknown         milky
# 9                  handpump        user-group    never pay          good
# 18                    other        user-group    never pay         milky
# 27                 handpump        user-group    never pay          good
# ...                     ...               ...          ...           ...
# 59329                 other        user-group      unknown         milky
# 59344               gravity           unknown      unknown       unknown
# 59362             rope pump        commercial    never pay          good
# 59370                 other           unknown      monthly       unknown
# 59383              handpump        user-group      unknown          good
#
#            quantity quantity_group                source source_class  \
# 4          seasonal       seasonal  rainwater harvesting      surface
# 7            enough         enough          shallow well  groundwater
# 9            enough         enough          shallow well  groundwater
# 18     insufficient   insufficient                spring  groundwater
# 27           enough         enough          shallow well  groundwater
# ...             ...            ...                   ...          ...
# 59329  insufficient   insufficient          shallow well  groundwater
# 59344       unknown        unknown                spring  groundwater
# 59362  insufficient   insufficient          shallow well  groundwater
# 59370       unknown        unknown               unknown      unknown
# 59383        enough         enough  rainwater harvesting      surface
#
#           waterpoint_type             status_group
# 4      communal standpipe               functional
# 7               hand pump           non functional
# 9               hand pump               functional
# 18                  other  functional needs repair
# 27              hand pump               functional
# ...                   ...                      ...
# 59329               other           non functional
# 59344  communal standpipe               functional
# 59362           hand pump               functional
# 59370               other               functional
# 59383           hand pump               functional
#
# [3877 rows x 23 columns]

# %%
pred_df['scheme_management'].value_counts()
# Out:
# VWC                 36793
# WUG                  5206
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1680
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64

# %%
pred_df["scheme_management"].fillna("VWC", inplace = True)

# %%
pred_df.isna().sum()
# Out:
# id                       0
# amount_tsh               0
# gps_height               0
# basin                    0
# region                   0
# region_code              0
# district_code            0
# lga                      0
# ward                     0
# population               0
# scheme_management        0
# construction_year        0
# extraction_type_group    0
# extraction_type_class    0
# management_group         0
# payment_type             0
# quality_group            0
# quantity                 0
# quantity_group           0
# source                   0
# source_class             0
# waterpoint_type          0
# status_group             0
# dtype: int64
